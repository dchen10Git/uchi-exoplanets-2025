# %% [markdown]
# # Kepler-80 Simulation

# %% [markdown]
# ### Simulation Set-up
# From the EU Exoplanet Catalog:
# <center>
# <img width=500 src="./Figures/kepler80_data.png"></img>
# </center>

# %% [markdown]
# The NASA Exoplanet Archive gives $<4459.73 M_\oplus$ for the mass of planet f and $<1.96262 M_\oplus$ for the mass of planet g.
# Assume Earth density for f, similar for g.

# %%
import rebound
import reboundx
import numpy as np
import matplotlib.pyplot as plt

# Create the simulation
sim = rebound.Simulation()
sim.units = ('AU', 'yr', 'Msun')
sim.integrator = "whfast"

# Add the star
sim.add(m=0.73)

# Define planet masses (converted to Msun)
masses = np.array([6.93, 6.741, 6.751, 4.129, 5, 5]) * 3.003e-6 # last 2 are placeholders

# Observed a values (ordered by letter)
a0 = np.array([6.48, 7.92, 3.72, 4.91, 1.75, 14]) * 0.01
